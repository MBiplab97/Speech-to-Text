# %%
# pip install SpeechRecognition

# %%
import speech_recognition as sr

# %%
r = sr.Recognizer()

# %%
with sr.AudioFile('audio1.wav') as source:   # Audio file could not be read as PCM WAV, AIFF/AIFF-C, or Native FLAC;
    audio_data = r.record(source)

# %%
result = r.recognize_google(audio_data)
print(result)
# Out:
# can you talking by the door
