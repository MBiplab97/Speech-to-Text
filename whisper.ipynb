# %%
pip install -U openai-whisper
# Out:
# Collecting openai-whisper
#   Using cached openai_whisper-20250625-py3-none-any.whl
# Collecting more-itertools (from openai-whisper)
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting numba (from openai-whisper)
#   Using cached numba-0.63.1-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy in e:\genai\whisper\.venv\lib\site-packages (from openai-whisper) (2.3.5)
# Collecting tiktoken (from openai-whisper)
#   Using cached tiktoken-0.12.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting torch (from openai-whisper)
#   Using cached torch-2.9.1-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: tqdm in e:\genai\whisper\.venv\lib\site-packages (from openai-whisper) (4.67.1)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba->openai-whisper)
#   Using cached llvmlite-0.46.0-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Collecting regex>=2022.1.18 (from tiktoken->openai-whisper)
#   Using cached regex-2025.11.3-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting requests>=2.26.0 (from tiktoken->openai-whisper)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.26.0->tiktoken->openai-whisper)
#   Using cached charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl.metadata (38 kB)
# Requirement already satisfied: idna<4,>=2.5 in e:\genai\whisper\.venv\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.11)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.26.0->tiktoken->openai-whisper)
#   Using cached urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi>=2017.4.17 in e:\genai\whisper\.venv\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2025.11.12)
# Requirement already satisfied: filelock in e:\genai\whisper\.venv\lib\site-packages (from torch->openai-whisper) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\genai\whisper\.venv\lib\site-packages (from torch->openai-whisper) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in e:\genai\whisper\.venv\lib\site-packages (from torch->openai-whisper) (1.14.0)
# Collecting networkx>=2.5.1 (from torch->openai-whisper)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch->openai-whisper)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: fsspec>=0.8.5 in e:\genai\whisper\.venv\lib\site-packages (from torch->openai-whisper) (2025.12.0)
# Requirement already satisfied: setuptools in e:\genai\whisper\.venv\lib\site-packages (from torch->openai-whisper) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\genai\whisper\.venv\lib\site-packages (from sympy>=1.13.3->torch->openai-whisper) (1.3.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->openai-whisper)
#   Using cached markupsafe-3.0.3-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: colorama in e:\genai\whisper\.venv\lib\site-packages (from tqdm->openai-whisper) (0.4.6)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Using cached numba-0.63.1-cp313-cp313-win_amd64.whl (2.8 MB)
# Using cached llvmlite-0.46.0-cp313-cp313-win_amd64.whl (38.1 MB)
# Using cached tiktoken-0.12.0-cp313-cp313-win_amd64.whl (879 kB)
# Using cached regex-2025.11.3-cp313-cp313-win_amd64.whl (277 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl (107 kB)
# Using cached urllib3-2.6.2-py3-none-any.whl (131 kB)
# Using cached torch-2.9.1-cp313-cp313-win_amd64.whl (110.9 MB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp313-cp313-win_amd64.whl (15 kB)
# Installing collected packages: urllib3, regex, networkx, more-itertools, MarkupSafe, llvmlite, charset_normalizer, requests, numba, jinja2, torch, tiktoken, openai-whisper
#
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    --- ------------------------------------  1/13 [regex]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    ------ ---------------------------------  2/13 [networkx]
#    --------- ------------------------------  3/13 [more-itertools]
#    --------------- ------------------------  5/13 [llvmlite]
#    --------------- ------------------------  5/13 [llvmlite]
#    --------------- ------------------------  5/13 [llvmlite]
#    --------------- ------------------------  5/13 [llvmlite]
#    --------------- ------------------------  5/13 [llvmlite]
#    --------------- ------------------------  5/13 [llvmlite]
#    --------------- ------------------------  5/13 [llvmlite]
#    ------------------ ---------------------  6/13 [charset_normalizer]
#    --------------------- ------------------  7/13 [requests]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    ------------------------------ --------- 10/13 [torch]
#    --------------------------------- ------ 11/13 [tiktoken]
#    --------------------------------- ------ 11/13 [tiktoken]
#    --------------------------------- ------ 11/13 [tiktoken]
#    --------------------------------- ------ 11/13 [tiktoken]
#    ------------------------------------ --- 12/13 [openai-whisper]
#    ---------------------------------------- 13/13 [openai-whisper]
#
# Successfully installed MarkupSafe-3.0.3 charset_normalizer-3.4.4 jinja2-3.1.6 llvmlite-0.46.0 more-itertools-10.8.0 networkx-3.6.1 numba-0.63.1 openai-whisper-20250625 regex-2025.11.3 requests-2.32.5 tiktoken-0.12.0 torch-2.9.1 urllib3-2.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import whisper

# %%
model = whisper.load_model("turbo")         # 1.5 gb model

# %%
import os
print(os.getcwd())
# Out:
# e:\GenAI\whisper

# %%
result = model.transcribe("audio1.mp3")
print(result["text"])
# Out:
# e:\GenAI\class11\.venv\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 result = model.transcribe("audio1.mp3")
#       2 print(result["text"])
#
# File e:\GenAI\class11\.venv\Lib\site-packages\whisper\transcribe.py:139, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, carry_initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, clip_timestamps, hallucination_silence_threshold, **decode_options)
#     136     decode_options["fp16"] = False
#     138 # Pad 30-seconds of silence to the input audio, for slicing
# --> 139 mel = log_mel_spectrogram(audio, model.dims.n_mels, padding=N_SAMPLES)
#     140 content_frames = mel.shape[-1] - N_FRAMES
#     141 content_duration = float(content_frames * HOP_LENGTH / SAMPLE_RATE)
#
# File e:\GenAI\class11\.venv\Lib\site-packages\whisper\audio.py:140, in log_mel_spectrogram(audio, n_mels, padding, device)
#     138 if not torch.is_tensor(audio):
#     139     if isinstance(audio, str):
# --> 140         audio = load_audio(audio)
#     141     audio = torch.from_numpy(audio)
#     143 if device is not None:
#
# File e:\GenAI\class11\.venv\Lib\site-packages\whisper\audio.py:58, in load_audio(file, sr)
#      56 # fmt: on
#      57 try:
# ---> 58     out = run(cmd, capture_output=True, check=True).stdout
#      59 except CalledProcessError as e:
#      60     raise RuntimeError(f"Failed to load audio: {e.stderr.decode()}") from e
#
# File D:\python\python 3.13.3\Lib\subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     551     kwargs['stdout'] = PIPE
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#     556         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File D:\python\python 3.13.3\Lib\subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035         if self.text_mode:
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#    1050     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File D:\python\python 3.13.3\Lib\subprocess.py:1551, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1549 # Start the process
#    1550 try:
# -> 1551     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1552                              # no special security
#    1553                              None, None,
#    1554                              int(not close_fds),
#    1555                              creationflags,
#    1556                              env,
#    1557                              cwd,
#    1558                              startupinfo)
#    1559 finally:
#    1560     # Child is launched. Close the parent's copy of those pipe
#    1561     # handles that only the child should have open.  You need
#    (...)   1564     # pipe will not close when the child process exits and the
#    1565     # ReadFile will hang.
#    1566     self._close_pipe_fds(p2cread, p2cwrite,
#    1567                          c2pread, c2pwrite,
#    1568                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %%
import os
print(os.path.exists(r"C:\Users\BIPLAB\Desktop\audio.mp3"))
# Out:
# True

# %%
# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("audio1.mp3")
audio = whisper.pad_or_trim(audio)

# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio, n_mels=model.dims.n_mels).to(model.device)

# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")

# decode the audio
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# print the recognized text
print(result.text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 # load audio and pad/trim it to fit 30 seconds
# ----> 2 audio = whisper.load_audio("audio1.mp3")
#       3 audio = whisper.pad_or_trim(audio)
#       5 # make log-Mel spectrogram and move to the same device as the model
#
# File e:\GenAI\class11\.venv\Lib\site-packages\whisper\audio.py:58, in load_audio(file, sr)
#      56 # fmt: on
#      57 try:
# ---> 58     out = run(cmd, capture_output=True, check=True).stdout
#      59 except CalledProcessError as e:
#      60     raise RuntimeError(f"Failed to load audio: {e.stderr.decode()}") from e
#
# File D:\python\python 3.13.3\Lib\subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     551     kwargs['stdout'] = PIPE
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#     556         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File D:\python\python 3.13.3\Lib\subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035         if self.text_mode:
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#    1050     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File D:\python\python 3.13.3\Lib\subprocess.py:1551, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1549 # Start the process
#    1550 try:
# -> 1551     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1552                              # no special security
#    1553                              None, None,
#    1554                              int(not close_fds),
#    1555                              creationflags,
#    1556                              env,
#    1557                              cwd,
#    1558                              startupinfo)
#    1559 finally:
#    1560     # Child is launched. Close the parent's copy of those pipe
#    1561     # handles that only the child should have open.  You need
#    (...)   1564     # pipe will not close when the child process exits and the
#    1565     # ReadFile will hang.
#    1566     self._close_pipe_fds(p2cread, p2cwrite,
#    1567                          c2pread, c2pwrite,
#    1568                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
